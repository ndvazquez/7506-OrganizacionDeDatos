# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt


df_original = pd.read_csv('events.csv', low_memory=False)

# %%
df_visited = df_original.loc[df_original['event']=='visited site',:]
df_visited['device_type'].value_counts().plot.bar()
plt.xlabel('Tipo de dispositivo', fontsize=15)
plt.ylabel('Entradas al sitio', fontsize=15)
plt.title('Cantidad de entradas al sitio por tipo de dispositivo', fontsize=20)
# Out:
# Text(0.5,1,'Cantidad de entradas al sitio por tipo de dispositivo')

# %%
entradas_por_chrome_mobile = df_visited.loc[(df_visited['browser_version'].str.contains('Chrome Mobile')) & (df_visited['device_type']=='Smartphone'),:]
entradas_por_chrome_mobile.size
# Out:
# 851644

# %%
entradas_por_safari = df_visited.loc[(df_visited['browser_version'].str.contains('Mobile Safari')) & (df_visited['device_type']=='Smartphone'),:]
entradas_por_safari.size
# Out:
# 69759

# %%
entradas_por_otro_navegador = df_visited.loc[df_visited['device_type']=='Smartphone',:].size
entradas_por_otro_navegador -= (entradas_por_safari.size + entradas_por_chrome_mobile.size)

# %%
plt.bar(height=[entradas_por_chrome_mobile.size, entradas_por_safari.size, entradas_por_otro_navegador], x=['Chrome Mobile', 'Safari Mobile', 'Otro'])
plt.xlabel('Navegadores', fontsize=15)
plt.ylabel('Entradas al sitio', fontsize=15)
plt.title('Entradas al sitio por dispositivos móviles separadas por navegador', fontsize=20)
# Out:
# Text(0.5,1,'Entradas al sitio por dispositivos móviles separadas por navegador')

# %%
mobile_entrys_df = df_visited.loc[df_visited['device_type']=='Smartphone',:]


android_users = mobile_entrys_df.loc[mobile_entrys_df['operating_system_version'].str.contains('Android'),:]
ios_users = mobile_entrys_df.loc[mobile_entrys_df['operating_system_version'].str.contains('iOS'),:]
display(android_users.size)
display(ios_users.size)
# Out:
# 929476
# 75969

# %%
other_so = df_visited.loc[df_visited['device_type']=='Smartphone',:].size
display(other_so)
other_so -= (android_users.size + ios_users.size)
display(other_so)
# Out:
# 1017497
# 12052

# %%
plt.bar(height=[android_users.size, ios_users.size, other_so], x=['Android', 'iOS', 'Otro'])
plt.xlabel('Sistemas Operativos', fontsize=15)
plt.ylabel('Entradas al sitio', fontsize=15)
plt.title('Entradas al sitio por dispositivos móviles separadas por sistema operativos', fontsize=20)
# Out:
# Text(0.5,1,'Entradas al sitio por dispositivos móviles separadas por sistema operativos')

# %%
grouped = df_visited.groupby(['new_vs_returning', 'device_type']).agg({'person':'count'})
grouped
# Out:
#                               person
# new_vs_returning device_type
# New              Computer      12073
#                  Smartphone    14305
#                  Tablet          478
#                  Unknown          42
# Returning        Computer      29717
#                  Smartphone    29934
#                  Tablet          756
#                  Unknown          73

# %%
df_visited = df_visited.dropna(how='all', axis=1)
df_visited
# Out:
#                    timestamp         event    person   channel  \
# 1        2018-05-31 23:38:05  visited site  0004b0a2      Paid
# 5        2018-05-29 13:29:26  visited site  0006a21a      Paid
# 9        2018-04-09 20:12:31  visited site  000a54b2      Paid
# 16       2018-05-24 11:21:07  visited site  000a54b2      Paid
# 45       2018-04-06 05:12:05  visited site  00184bf9   Organic
# 87       2018-05-04 18:47:03  visited site  00184bf9    Direct
# 96       2018-05-17 00:08:56  visited site  0019c395      Paid
# 106      2018-06-06 18:40:53  visited site  001bb7eb   Organic
# 108      2018-06-08 12:15:33  visited site  001bb7eb      Paid
# 112      2018-05-29 12:56:08  visited site  001f1653      Paid
# 116      2018-01-18 00:19:39  visited site  00204059    Direct
# 118      2018-01-31 16:54:29  visited site  00204059    Social
# 127      2018-02-01 23:16:05  visited site  00204059  Referral
# 144      2018-02-02 17:37:14  visited site  00204059      Paid
# 154      2018-02-06 02:27:23  visited site  00204059   Organic
# 168      2018-02-08 02:51:17  visited site  00204059    Direct
# 175      2018-02-14 20:34:18  visited site  00204059    Direct
# 190      2018-02-15 14:19:04  visited site  00204059    Direct
# 203      2018-02-15 22:09:37  visited site  00204059    Direct
# 206      2018-02-15 22:53:06  visited site  00204059  Referral
# 210      2018-02-16 00:21:43  visited site  00204059    Direct
# 221      2018-05-19 03:36:01  visited site  00204059  Referral
# 227      2018-05-30 16:05:19  visited site  0024a82b      Paid
# 235      2018-05-21 19:47:49  visited site  0024ad28   Organic
# 244      2018-05-24 15:13:12  visited site  0024ad28      Paid
# 252      2018-05-28 22:42:17  visited site  0024ad28      Paid
# 258      2018-05-14 23:42:08  visited site  00269e77      Paid
# 261      2018-06-05 01:06:49  visited site  00269e77      Paid
# 266      2018-06-07 01:59:39  visited site  00269e77      Paid
# 268      2018-06-07 21:40:45  visited site  00269e77      Paid
# ...                      ...           ...       ...       ...
# 1010880  2018-06-04 22:39:42  visited site  ffe129fe      Paid
# 1010890  2018-05-25 13:27:50  visited site  ffe1bfe7      Paid
# 1010938  2018-05-25 15:18:55  visited site  ffe1bfe7    Direct
# 1010949  2018-06-15 20:18:03  visited site  ffe1f855      Paid
# 1010986  2018-06-08 19:17:27  visited site  ffe226f0      Paid
# 1011011  2018-05-17 13:04:38  visited site  ffe741db      Paid
# 1011018  2018-05-15 15:36:29  visited site  ffeaaa70      Paid
# 1011027  2018-05-15 18:16:45  visited site  ffeaaa70      Paid
# 1011036  2018-06-02 12:43:02  visited site  ffeaaa70      Paid
# 1011045  2018-06-11 23:00:22  visited site  ffeb3a03      Paid
# 1011049  2018-06-13 23:59:27  visited site  ffeb3a03      Paid
# 1011055  2018-06-08 18:27:59  visited site  ffef9da6      Paid
# 1011060  2018-01-24 00:10:52  visited site  fff0e00c      Paid
# 1011064  2018-05-23 23:20:27  visited site  fff0e00c   Organic
# 1011127  2018-05-30 17:51:28  visited site  fff0e00c   Organic
# 1011148  2018-05-30 18:38:52  visited site  fff0e00c  Referral
# 1011181  2018-06-08 11:51:06  visited site  fff225f8      Paid
# 1011190  2018-06-07 21:37:08  visited site  fff229f7      Paid
# 1011200  2018-06-07 22:18:29  visited site  fff229f7   Organic
# 1011206  2018-05-16 21:05:43  visited site  fff568f7   Organic
# 1011208  2018-05-17 14:42:19  visited site  fff568f7      Paid
# 1011221  2018-05-21 11:10:32  visited site  fff568f7      Paid
# 1011232  2018-05-25 18:19:44  visited site  fff60213      Paid
# 1011236  2018-05-28 18:19:27  visited site  fff99b85      Paid
# 1011243  2018-05-15 18:30:07  visited site  ffff8106      Paid
# 1011251  2018-05-18 00:29:38  visited site  ffffa8d1      Paid
# 1011258  2018-06-09 13:40:05  visited site  ffffa8d1      Paid
# 1011273  2018-06-09 15:39:56  visited site  ffffa8d1  Referral
# 1011277  2018-06-11 12:25:40  visited site  ffffa8d1      Paid
# 1011284  2018-06-04 23:18:03  visited site  ffffac8a      Paid
#
#         new_vs_returning                 city             region  country  \
# 1                    New           Camaragibe         Pernambuco   Brazil
# 5                    New       Rio de Janeiro     Rio de Janeiro   Brazil
# 9                    New       Rio de Janeiro     Rio de Janeiro   Brazil
# 16             Returning       Rio de Janeiro     Rio de Janeiro   Brazil
# 45                   New       Ribeirão Preto          Sao Paulo   Brazil
# 87             Returning       Ribeirão Preto          Sao Paulo   Brazil
# 96                   New              Unknown            Unknown   Brazil
# 106                  New              Unknown            Unknown   Brazil
# 108            Returning              Unknown            Unknown   Brazil
# 112                  New              Unknown            Unknown   Brazil
# 116                  New              Unknown            Unknown  Unknown
# 118            Returning              Unknown            Unknown  Unknown
# 127            Returning              Unknown            Unknown  Unknown
# 144            Returning              Unknown            Unknown  Unknown
# 154            Returning              Unknown            Unknown  Unknown
# 168            Returning              Unknown            Unknown  Unknown
# 175            Returning              Unknown            Unknown  Unknown
# 190            Returning              Unknown            Unknown  Unknown
# 203            Returning              Unknown            Unknown  Unknown
# 206            Returning              Unknown            Unknown  Unknown
# 210            Returning              Unknown            Unknown  Unknown
# 221            Returning              Unknown            Unknown  Unknown
# 227                  New              Unknown            Unknown   Brazil
# 235                  New         Porto Alegre  Rio Grande do Sul   Brazil
# 244            Returning    Santa Cruz do Sul  Rio Grande do Sul   Brazil
# 252            Returning         Porto Alegre  Rio Grande do Sul   Brazil
# 258                  New              Unknown            Unknown  Unknown
# 261            Returning              Unknown            Unknown  Unknown
# 266            Returning              Unknown            Unknown  Unknown
# 268            Returning              Unknown            Unknown  Unknown
# ...                  ...                  ...                ...      ...
# 1010880              New          Sao Goncalo     Rio de Janeiro   Brazil
# 1010890              New               Franca          Sao Paulo   Brazil
# 1010938        Returning               Franca          Sao Paulo   Brazil
# 1010949              New              Unknown            Unknown  Unknown
# 1010986              New       Rio de Janeiro     Rio de Janeiro   Brazil
# 1011011              New      Cerqueira Cesar          Sao Paulo   Brazil
# 1011018              New              Vitória     Espirito Santo   Brazil
# 1011027        Returning              Vitória     Espirito Santo   Brazil
# 1011036        Returning              Vitória     Espirito Santo   Brazil
# 1011045              New            São Paulo          Sao Paulo   Brazil
# 1011049        Returning            São Paulo          Sao Paulo   Brazil
# 1011055              New       Belo Horizonte       Minas Gerais   Brazil
# 1011060              New               Recife         Pernambuco   Brazil
# 1011064        Returning               Recife         Pernambuco   Brazil
# 1011127        Returning               Recife         Pernambuco   Brazil
# 1011148        Returning               Recife         Pernambuco   Brazil
# 1011181              New           Ananindeua               Para   Brazil
# 1011190              New               Recife         Pernambuco   Brazil
# 1011200        Returning               Recife         Pernambuco   Brazil
# 1011206              New       Ribeirão Preto          Sao Paulo   Brazil
# 1011208        Returning       Ribeirão Preto          Sao Paulo   Brazil
# 1011221        Returning       Ribeirão Preto          Sao Paulo   Brazil
# 1011232              New              Barueri          Sao Paulo   Brazil
# 1011236              New         Frecheirinha              Ceara   Brazil
# 1011243              New                 Iepe          Sao Paulo   Brazil
# 1011251              New  Sao Pedro da Aldeia     Rio de Janeiro   Brazil
# 1011258        Returning           Leopoldina       Minas Gerais   Brazil
# 1011273        Returning           Leopoldina       Minas Gerais   Brazil
# 1011277        Returning           Cataguases       Minas Gerais   Brazil
# 1011284              New              Unknown            Unknown   Brazil
#
#         device_type screen_resolution operating_system_version  \
# 1        Smartphone           360x640                Android 6
# 5        Smartphone           360x640            Android 5.1.1
# 9          Computer         1920x1080              Windows 10
# 16         Computer         1920x1080              Windows 10
# 45         Computer          1366x768              Windows 10
# 87         Computer          1366x768              Windows 10
# 96       Smartphone           360x640                Android 6
# 106        Computer          1366x768               Windows 7
# 108        Computer          1366x768               Windows 7
# 112      Smartphone           320x570                Android 6
# 116        Computer          1024x600               Windows 7
# 118        Computer          1024x600               Windows 7
# 127        Computer          1024x600               Windows 7
# 144        Computer          1024x600               Windows 7
# 154        Computer          1024x600               Windows 7
# 168        Computer          1024x600               Windows 7
# 175        Computer          1024x600               Windows 7
# 190        Computer          1024x600               Windows 7
# 203        Computer          1024x600               Windows 7
# 206        Computer          1024x600               Windows 7
# 210        Computer          1024x600               Windows 7
# 221        Computer          1360x768              Windows 10
# 227        Computer          1366x768               Windows 7
# 235        Computer          1280x800               Windows 7
# 244        Computer          1280x800               Windows 7
# 252        Computer          1280x800               Windows 7
# 258      Smartphone           320x534            Android 5.1.1
# 261      Smartphone           320x534            Android 5.1.1
# 266      Smartphone           320x534            Android 5.1.1
# 268      Smartphone           320x534            Android 5.1.1
# ...             ...               ...                      ...
# 1010880  Smartphone           320x534            Android 5.0.2
# 1010890    Computer          1366x768               Windows 7
# 1010938    Computer          1366x768               Windows 7
# 1010949    Computer         1920x1080              Windows 10
# 1010986    Computer         1280x1024              Windows 10
# 1011011    Computer          1024x768               Windows 7
# 1011018    Computer          1024x768               Windows 7
# 1011027    Computer          1024x768               Windows 7
# 1011036    Computer          1024x768               Windows 7
# 1011045    Computer          1366x768               Windows 7
# 1011049    Computer          1366x768               Windows 7
# 1011055    Computer          1366x768               Windows 7
# 1011060    Computer          1280x800               Windows 7
# 1011064    Computer          1280x800               Windows 7
# 1011127    Computer          1280x800               Windows 7
# 1011148    Computer          1280x800               Windows 7
# 1011181  Smartphone           360x640            Android 6.0.1
# 1011190    Computer          1366x768              Windows 10
# 1011200    Computer          1366x768              Windows 10
# 1011206    Computer          1024x768               Windows 7
# 1011208    Computer          1024x768               Windows 7
# 1011221    Computer          1024x768               Windows 7
# 1011232  Smartphone           360x640            Android 7.1.1
# 1011236    Computer          1024x820               Windows 8
# 1011243      Tablet          600x1024            Android 7.1.1
# 1011251    Computer          1366x768             Windows 8.1
# 1011258    Computer          1366x768             Windows 8.1
# 1011273    Computer          1366x768             Windows 8.1
# 1011277    Computer          1366x768             Windows 8.1
# 1011284  Smartphone           320x534                Android 6
#
#             browser_version
# 1          Chrome Mobile 39
# 5               Android 5.1
# 9               Chrome 65.0
# 16              Chrome 66.0
# 45              Chrome 65.0
# 87              Chrome 66.0
# 96       Chrome Mobile 66.0
# 106              Firefox 52
# 108              Firefox 52
# 112        Chrome Mobile 39
# 116             Chrome 63.0
# 118             Chrome 63.0
# 127             Chrome 63.0
# 144             Chrome 63.0
# 154             Chrome 63.0
# 168             Chrome 63.0
# 175             Chrome 64.0
# 190             Chrome 64.0
# 203             Chrome 64.0
# 206             Chrome 64.0
# 210             Chrome 64.0
# 221              Opera 52.0
# 227             Chrome 66.0
# 235                   IE 11
# 244                   IE 11
# 252                   IE 11
# 258      Chrome Mobile 66.0
# 261      Chrome Mobile 67.0
# 266      Chrome Mobile 67.0
# 268      Chrome Mobile 67.0
# ...                     ...
# 1010880  Chrome Mobile 66.0
# 1010890         Chrome 66.0
# 1010938         Chrome 66.0
# 1010949         Chrome 67.0
# 1010986         Chrome 66.0
# 1011011         Chrome 66.0
# 1011018         Chrome 66.0
# 1011027         Chrome 66.0
# 1011036         Chrome 66.0
# 1011045         Chrome 66.0
# 1011049         Chrome 66.0
# 1011055               IE 11
# 1011060          Firefox 47
# 1011064          Firefox 47
# 1011127          Firefox 47
# 1011148          Firefox 47
# 1011181        Facebook 169
# 1011190         Chrome 66.0
# 1011200         Chrome 66.0
# 1011206         Chrome 66.0
# 1011208         Chrome 66.0
# 1011221         Chrome 66.0
# 1011232  Chrome Mobile 66.0
# 1011236         Chrome 66.0
# 1011243         Chrome 66.0
# 1011251         Chrome 66.0
# 1011258         Chrome 67.0
# 1011273         Chrome 67.0
# 1011277         Chrome 67.0
# 1011284    Chrome Mobile 39
#
# [87378 rows x 12 columns]

# %%
grouped = df_visited.groupby(['channel', 'device_type']).agg({'person':'count'})
grouped.columns = ['amount']
grouped
# Out:
#                       amount
# channel  device_type
# Direct   Computer      10602
#          Smartphone     7754
#          Tablet          141
#          Unknown          25
# Email    Computer         27
#          Smartphone       49
# Organic  Computer       5842
#          Smartphone     6349
#          Tablet          142
#          Unknown          15
# Paid     Computer      20827
#          Smartphone    22581
#          Tablet          739
#          Unknown          46
# Referral Computer       4232
#          Smartphone     6928
#          Tablet          195
#          Unknown          29
# Social   Computer        251
#          Smartphone      578
#          Tablet           17
# Unknown  Computer          9
